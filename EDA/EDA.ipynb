# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

with open("/content/drive/MyDrive/streamlit_cancer_predict_app/data/wdbc.names", "r") as file:
    content = file.read()
    print(content)
# Out:
# 1. Title: Wisconsin Diagnostic Breast Cancer (WDBC)
#
# 2. Source Information
#
# a) Creators:
#
# 	Dr. William H. Wolberg, General Surgery Dept., University of
# 	Wisconsin,  Clinical Sciences Center, Madison, WI 53792
# 	wolberg@eagle.surgery.wisc.edu
#
# 	W. Nick Street, Computer Sciences Dept., University of
# 	Wisconsin, 1210 West Dayton St., Madison, WI 53706
# 	street@cs.wisc.edu  608-262-6619
#
# 	Olvi L. Mangasarian, Computer Sciences Dept., University of
# 	Wisconsin, 1210 West Dayton St., Madison, WI 53706
# 	olvi@cs.wisc.edu
#
# b) Donor: Nick Street
#
# c) Date: November 1995
#
# 3. Past Usage:
#
# first usage:
#
# 	W.N. Street, W.H. Wolberg and O.L. Mangasarian
# 	Nuclear feature extraction for breast tumor diagnosis.
# 	IS&T/SPIE 1993 International Symposium on Electronic Imaging: Science
# 	and Technology, volume 1905, pages 861-870, San Jose, CA, 1993.
#
# OR literature:
#
# 	O.L. Mangasarian, W.N. Street and W.H. Wolberg.
# ...

# %%
features = ["radius","texture","perimeter", "area", "smoothness" , "compactness", "concavity", "concave points" , "symmetry ", "fractal dimension"]

complete_features = ["ID", "diagnosis"]
for f in features:
  complete_features.append(f + "_mean")
  complete_features.append(f + "_se")
  complete_features.append(f + "_worst")
complete_features

# %%
df = pd.read_csv("/content/drive/MyDrive/streamlit_cancer_predict_app/data/wdbc.data", names=complete_features, index_col = 0)
df.head()
df.info() #no missing values, dtypes correct
df["diagnosis"].unique()
df["diagnosis"].replace({"M": "Malignant" , "B": "Beningn"}, inplace=True)

# %%
df["diagnosis"].unique()
# Out:
# array(['Malignant', 'Beningn'], dtype=object)
